# %% [markdown]
# ### Set-up

# %%
import pandas as pd
import numpy as np

# %%
adult_income = pd.read_csv("adult-income.csv")
adult_income = adult_income.rename(columns={"39": "Age", " State-gov": "Workclass", " 77516": "Final_weight", 
                             " Bachelors": "Education", " 13": "Education_num", " Never-married": "Marital_status", 
                             " Adm-clerical": "Occupation", " Not-in-family": "Relationship", " White": "Race", 
                             " Male": "Gender", " 2174": "Capital_gain", " 0": "Capital_loss", 
                             " 40": "hours-per-week", " United-States": "Native_country", 
                             " <=50K": "Income_bracket"})
adult_income.head()
# Out:
#    Age          Workclass  Final_weight   Education  Education_num  \
# 0   50   Self-emp-not-inc         83311   Bachelors             13
# 1   38            Private        215646     HS-grad              9
# 2   53            Private        234721        11th              7
# 3   28            Private        338409   Bachelors             13
# 4   37            Private        284582     Masters             14
#
#         Marital_status          Occupation    Relationship    Race   Gender  \
# 0   Married-civ-spouse     Exec-managerial         Husband   White     Male
# 1             Divorced   Handlers-cleaners   Not-in-family   White     Male
# 2   Married-civ-spouse   Handlers-cleaners         Husband   Black     Male
# 3   Married-civ-spouse      Prof-specialty            Wife   Black   Female
# 4   Married-civ-spouse     Exec-managerial            Wife   White   Female
#
#    Capital_gain  Capital_loss  hours-per-week  Native_country Income_bracket
# 0             0             0              13   United-States          <=50K
# 1             0             0              40   United-States          <=50K
# 2             0             0              40   United-States          <=50K
# 3             0             0              40            Cuba          <=50K
# 4             0             0              40   United-States          <=50K

# %% [markdown]
# ### Indexing and Slicing

# %%
selected_col = adult_income["Income_bracket"]
 
# display first few elements
selected_col.head()
# Out:
# 0     <=50K
# 1     <=50K
# 2     <=50K
# 3     <=50K
# 4     <=50K
# Name: Income_bracket, dtype: object

# %%
# form a list of column labels 
cols = ["Education", "Gender", "hours-per-week", "Income_bracket"]
 
# form the subset
subset = adult_income[cols]
 
# display first few rows
subset.head()
# Out:
#     Education   Gender  hours-per-week Income_bracket
# 0   Bachelors     Male              13          <=50K
# 1     HS-grad     Male              40          <=50K
# 2        11th     Male              40          <=50K
# 3   Bachelors   Female              40          <=50K
# 4     Masters   Female              40          <=50K

# %%
cols = ["Education"]
subset = adult_income[cols]
subset.head()
# Out:
#     Education
# 0   Bachelors
# 1     HS-grad
# 2        11th
# 3   Bachelors
# 4     Masters

# %%
selected_col = adult_income.Education
 
# display first few elements
selected_col.head()
# Out:
# 0     Bachelors
# 1       HS-grad
# 2          11th
# 3     Bachelors
# 4       Masters
# Name: Education, dtype: object

# %%
# subset of DataFrame from row 5 to row 10
adult_income[5:11]
# Out:
#     Age          Workclass  Final_weight      Education  Education_num  \
# 5    49            Private        160187            9th              5
# 6    52   Self-emp-not-inc        209642        HS-grad              9
# 7    31            Private         45781        Masters             14
# 8    42            Private        159449      Bachelors             13
# 9    37            Private        280464   Some-college             10
# 10   30          State-gov        141297      Bachelors             13
#
#             Marital_status        Occupation    Relationship  \
# 5    Married-spouse-absent     Other-service   Not-in-family
# 6       Married-civ-spouse   Exec-managerial         Husband
# 7            Never-married    Prof-specialty   Not-in-family
# 8       Married-civ-spouse   Exec-managerial         Husband
# 9       Married-civ-spouse   Exec-managerial         Husband
# 10      Married-civ-spouse    Prof-specialty         Husband
#
#                    Race   Gender  Capital_gain  Capital_loss  hours-per-week  \
# 5                 Black   Female             0             0              16
# 6                 White     Male             0             0              45
# 7                 White   Female         14084             0              50
# 8                 White     Male          5178             0              40
# 9                 Black     Male             0             0              80
# 10   Asian-Pac-Islander     Male             0             0              40
#
#     Native_country Income_bracket
# 5          Jamaica          <=50K
# 6    United-States           >50K
# 7    United-States           >50K
# 8    United-States           >50K
# 9    United-States           >50K
# 10           India           >50K

# %%
# subset of DataFrame from row 1 to row 5
adult_income[:6]
# Out:
#    Age          Workclass  Final_weight   Education  Education_num  \
# 0   50   Self-emp-not-inc         83311   Bachelors             13
# 1   38            Private        215646     HS-grad              9
# 2   53            Private        234721        11th              7
# 3   28            Private        338409   Bachelors             13
# 4   37            Private        284582     Masters             14
# 5   49            Private        160187         9th              5
#
#            Marital_status          Occupation    Relationship    Race  \
# 0      Married-civ-spouse     Exec-managerial         Husband   White
# 1                Divorced   Handlers-cleaners   Not-in-family   White
# 2      Married-civ-spouse   Handlers-cleaners         Husband   Black
# 3      Married-civ-spouse      Prof-specialty            Wife   Black
# 4      Married-civ-spouse     Exec-managerial            Wife   White
# 5   Married-spouse-absent       Other-service   Not-in-family   Black
#
#     Gender  Capital_gain  Capital_loss  hours-per-week  Native_country  \
# 0     Male             0             0              13   United-States
# 1     Male             0             0              40   United-States
# 2     Male             0             0              40   United-States
# 3   Female             0             0              40            Cuba
# 4   Female             0             0              40   United-States
# 5   Female             0             0              16         Jamaica
#
#   Income_bracket
# 0          <=50K
# 1          <=50K
# 2          <=50K
# 3          <=50K
# 4          <=50K
# 5          <=50K

# %%
# the last row 
adult_income[-1:]
# Out:
#        Age      Workclass  Final_weight Education  Education_num  \
# 32559   52   Self-emp-inc        287927   HS-grad              9
#
#             Marital_status        Occupation Relationship    Race   Gender  \
# 32559   Married-civ-spouse   Exec-managerial         Wife   White   Female
#
#        Capital_gain  Capital_loss  hours-per-week  Native_country  \
# 32559         15024             0              40   United-States
#
#       Income_bracket
# 32559           >50K

# %% [markdown]
# ### Indexing and slicing with iloc

# %%
subset = adult_income.iloc[[0,1,2,5], :]
subset
# Out:
#    Age          Workclass  Final_weight   Education  Education_num  \
# 0   50   Self-emp-not-inc         83311   Bachelors             13
# 1   38            Private        215646     HS-grad              9
# 2   53            Private        234721        11th              7
# 5   49            Private        160187         9th              5
#
#            Marital_status          Occupation    Relationship    Race  \
# 0      Married-civ-spouse     Exec-managerial         Husband   White
# 1                Divorced   Handlers-cleaners   Not-in-family   White
# 2      Married-civ-spouse   Handlers-cleaners         Husband   Black
# 5   Married-spouse-absent       Other-service   Not-in-family   Black
#
#     Gender  Capital_gain  Capital_loss  hours-per-week  Native_country  \
# 0     Male             0             0              13   United-States
# 1     Male             0             0              40   United-States
# 2     Male             0             0              40   United-States
# 5   Female             0             0              16         Jamaica
#
#   Income_bracket
# 0          <=50K
# 1          <=50K
# 2          <=50K
# 5          <=50K

# %%
subset = adult_income.iloc[:, 0:3] 
subset.head()
# Out:
#    Age          Workclass  Final_weight
# 0   50   Self-emp-not-inc         83311
# 1   38            Private        215646
# 2   53            Private        234721
# 3   28            Private        338409
# 4   37            Private        284582

# %%
column = adult_income.iloc[:, 2]
column.head()
# Out:
# 0     83311
# 1    215646
# 2    234721
# 3    338409
# 4    284582
# Name: Final_weight, dtype: int64

# %%
row = adult_income.iloc[4, :]
row
# Out:
# Age                                37
# Workclass                     Private
# Final_weight                   284582
# Education                     Masters
# Education_num                      14
# Marital_status     Married-civ-spouse
# Occupation            Exec-managerial
# Relationship                     Wife
# Race                            White
# Gender                         Female
# Capital_gain                        0
# Capital_loss                        0
# hours-per-week                     40
# Native_country          United-States
# Income_bracket                  <=50K
# Name: 4, dtype: object

# %%
value = adult_income.iloc[4, 2]
value
# Out:
# 284582

# %% [markdown]
# ### Indexing and slicing with loc

# %%
subset = adult_income.loc[10:15, 'Education_num':'hours-per-week']
subset
# Out:
#     Education_num       Marital_status         Occupation    Relationship  \
# 10             13   Married-civ-spouse     Prof-specialty         Husband
# 11             13        Never-married       Adm-clerical       Own-child
# 12             12        Never-married              Sales   Not-in-family
# 13             11   Married-civ-spouse       Craft-repair         Husband
# 14              4   Married-civ-spouse   Transport-moving         Husband
# 15              9        Never-married    Farming-fishing       Own-child
#
#                    Race   Gender  Capital_gain  Capital_loss  hours-per-week
# 10   Asian-Pac-Islander     Male             0             0              40
# 11                White   Female             0             0              30
# 12                Black     Male             0             0              50
# 13   Asian-Pac-Islander     Male             0             0              40
# 14   Amer-Indian-Eskimo     Male             0             0              45
# 15                White     Male             0             0              35

# %%
subset = adult_income.loc[[2, 4, 6, 8], :]
subset
# Out:
#    Age          Workclass  Final_weight   Education  Education_num  \
# 2   53            Private        234721        11th              7
# 4   37            Private        284582     Masters             14
# 6   52   Self-emp-not-inc        209642     HS-grad              9
# 8   42            Private        159449   Bachelors             13
#
#         Marital_status          Occupation Relationship    Race   Gender  \
# 2   Married-civ-spouse   Handlers-cleaners      Husband   Black     Male
# 4   Married-civ-spouse     Exec-managerial         Wife   White   Female
# 6   Married-civ-spouse     Exec-managerial      Husband   White     Male
# 8   Married-civ-spouse     Exec-managerial      Husband   White     Male
#
#    Capital_gain  Capital_loss  hours-per-week  Native_country Income_bracket
# 2             0             0              40   United-States          <=50K
# 4             0             0              40   United-States          <=50K
# 6             0             0              45   United-States           >50K
# 8          5178             0              40   United-States           >50K

# %%
df_100 = adult_income.iloc[100:, :]
# display first few rows
df_100.head()
# Out:
#      Age          Workclass  Final_weight      Education  Education_num  \
# 100   44            Private        198282      Bachelors             13
# 101   47   Self-emp-not-inc        149116        Masters             14
# 102   20            Private        188300   Some-college             10
# 103   29            Private        103432        HS-grad              9
# 104   32       Self-emp-inc        317660        HS-grad              9
#
#           Marital_status        Occupation    Relationship    Race   Gender  \
# 100   Married-civ-spouse   Exec-managerial         Husband   White     Male
# 101        Never-married    Prof-specialty   Not-in-family   White   Female
# 102        Never-married      Tech-support       Own-child   White   Female
# 103        Never-married      Craft-repair   Not-in-family   White     Male
# 104   Married-civ-spouse      Craft-repair         Husband   White     Male
#
#      Capital_gain  Capital_loss  hours-per-week  Native_country Income_bracket
# 100         15024             0              60   United-States           >50K
# 101             0             0              50   United-States          <=50K
# 102             0             0              40   United-States          <=50K
# 103             0             0              40   United-States          <=50K
# 104          7688             0              40   United-States           >50K

# %%
print('.loc[105:110, :] -- gives rows matching that *index*')
print(df_100.loc[105:110, :])
print('') 
print('[105:110] -- (without loc) gives rows from *position* 105 to 110')
print(df_100[105:110])
print('')
print('iloc[105:110, :] -- also gives rows from *position* 105 to 110')
print(df_100.iloc[105:110, :])
# Out:
# .loc[105:110, :] -- gives rows matching that *index*
#      Age   Workclass  Final_weight     Education  Education_num  \
# 105   17           ?        304873          10th              6
# 106   30     Private        194901          11th              7
# 107   31   Local-gov        189265       HS-grad              9
# 108   42     Private        124692       HS-grad              9
# 109   24     Private        432376     Bachelors             13
# 110   38     Private         65324   Prof-school             15
#
#           Marital_status          Occupation     Relationship    Race  \
# 105        Never-married                   ?        Own-child   White
# 106        Never-married   Handlers-cleaners        Own-child   White
# 107        Never-married        Adm-clerical    Not-in-family   White
# 108   Married-civ-spouse   Handlers-cleaners          Husband   White
# 109        Never-married               Sales   Other-relative   White
# 110   Married-civ-spouse      Prof-specialty          Husband   White
#
#       Gender  Capital_gain  Capital_loss  hours-per-week  Native_country  \
# 105   Female         34095             0              32   United-States
# 106     Male             0             0              40   United-States
# 107   Female             0             0              40   United-States
# 108     Male             0             0              40   United-States
# 109     Male             0             0              40   United-States
# 110     Male             0             0              40   United-States
#
#     Income_bracket
# 105          <=50K
# 106          <=50K
# 107          <=50K
# 108          <=50K
# 109          <=50K
# 110           >50K
#
# [105:110] -- (without loc) gives rows from *position* 105 to 110
#      Age      Workclass  Final_weight   Education  Education_num  \
# 205   36        Private        128757   Bachelors             13
# 206   35        Private         36270     HS-grad              9
# 207   58   Self-emp-inc        210563     HS-grad              9
# 208   17        Private         65368        11th              7
# 209   44      Local-gov        160943     HS-grad              9
#
#           Marital_status         Occupation    Relationship    Race   Gender  \
# 205   Married-civ-spouse      Other-service         Husband   Black     Male
# 206             Divorced       Craft-repair   Not-in-family   White     Male
# 207   Married-civ-spouse              Sales            Wife   White   Female
# 208        Never-married              Sales       Own-child   White   Female
# 209   Married-civ-spouse   Transport-moving         Husband   Black     Male
#
#      Capital_gain  Capital_loss  hours-per-week  Native_country Income_bracket
# 205          7298             0              36   United-States           >50K
# 206             0             0              60   United-States          <=50K
# 207         15024             0              35   United-States           >50K
# 208             0             0              12   United-States          <=50K
# 209             0             0              40   United-States          <=50K
#
# iloc[105:110, :] -- also gives rows from *position* 105 to 110
#      Age      Workclass  Final_weight   Education  Education_num  \
# 205   36        Private        128757   Bachelors             13
# 206   35        Private         36270     HS-grad              9
# 207   58   Self-emp-inc        210563     HS-grad              9
# 208   17        Private         65368        11th              7
# 209   44      Local-gov        160943     HS-grad              9
#
#           Marital_status         Occupation    Relationship    Race   Gender  \
# 205   Married-civ-spouse      Other-service         Husband   Black     Male
# 206             Divorced       Craft-repair   Not-in-family   White     Male
# 207   Married-civ-spouse              Sales            Wife   White   Female
# 208        Never-married              Sales       Own-child   White   Female
# 209   Married-civ-spouse   Transport-moving         Husband   Black     Male
#
#      Capital_gain  Capital_loss  hours-per-week  Native_country Income_bracket
# 205          7298             0              36   United-States           >50K
# 206             0             0              60   United-States          <=50K
# 207         15024             0              35   United-States           >50K
# 208             0             0              12   United-States          <=50K
# 209             0             0              40   United-States          <=50K

# %% [markdown]
# ### Single value with loc

# %%
column = adult_income.loc[:, "Gender"]
column.head()
# Out:
# 0       Male
# 1       Male
# 2       Male
# 3     Female
# 4     Female
# Name: Gender, dtype: object

# %%
row = adult_income.loc[2, :] 
row
# Out:
# Age                                53
# Workclass                     Private
# Final_weight                   234721
# Education                        11th
# Education_num                       7
# Marital_status     Married-civ-spouse
# Occupation          Handlers-cleaners
# Relationship                  Husband
# Race                            Black
# Gender                           Male
# Capital_gain                        0
# Capital_loss                        0
# hours-per-week                     40
# Native_country          United-States
# Income_bracket                  <=50K
# Name: 2, dtype: object

# %%
print('sex of person at row index 2')
print(adult_income.loc[2, 'Gender'])
print('education of person at row index 4')
print(adult_income.loc[4, 'Education'])
# Out:
# sex of person at row index 2
#  Male
# education of person at row index 4
#  Masters

# %% [markdown]
# ### Chained Indexing

# %%
subset = adult_income.iloc[100:, :].iloc[105:110, :]
subset
# Out:
#      Age      Workclass  Final_weight   Education  Education_num  \
# 205   36        Private        128757   Bachelors             13
# 206   35        Private         36270     HS-grad              9
# 207   58   Self-emp-inc        210563     HS-grad              9
# 208   17        Private         65368        11th              7
# 209   44      Local-gov        160943     HS-grad              9
#
#           Marital_status         Occupation    Relationship    Race   Gender  \
# 205   Married-civ-spouse      Other-service         Husband   Black     Male
# 206             Divorced       Craft-repair   Not-in-family   White     Male
# 207   Married-civ-spouse              Sales            Wife   White   Female
# 208        Never-married              Sales       Own-child   White   Female
# 209   Married-civ-spouse   Transport-moving         Husband   Black     Male
#
#      Capital_gain  Capital_loss  hours-per-week  Native_country Income_bracket
# 205          7298             0              36   United-States           >50K
# 206             0             0              60   United-States          <=50K
# 207         15024             0              35   United-States           >50K
# 208             0             0              12   United-States          <=50K
# 209             0             0              40   United-States          <=50K

# %%
subset = adult_income[25:30][['Education', 'Income_bracket']]
subset
# Out:
#         Education Income_bracket
# 25        HS-grad          <=50K
# 26   Some-college           >50K
# 27        HS-grad          <=50K
# 28        HS-grad          <=50K
# 29     Assoc-acdm          <=50K

# %%
print(adult_income.iloc[10, :].loc[:, 'hours_per_week'])
# Out:
# ---------------------------------------------------------------------------
# IndexingError                             Traceback (most recent call last)
# <ipython-input-41-b9e320e3b64c> in <module>()
# ----> 1 print(adult_income.iloc[10, :].loc[:, 'hours_per_week'])
#
# /anaconda/lib/python3.6/site-packages/pandas/core/indexing.py in __getitem__(self, key)
#    1402                 except (KeyError, IndexError, AttributeError):
#    1403                     pass
# -> 1404             return self._getitem_tuple(key)
#    1405         else:
#    1406             # we by definition only have the 0th axis
#
# /anaconda/lib/python3.6/site-packages/pandas/core/indexing.py in _getitem_tuple(self, tup)
#     794
#     795         # no multi-index, so validate all of the indexers
# --> 796         self._has_valid_tuple(tup)
#     797
#     798         # ugly hack for GH #836
#
# /anaconda/lib/python3.6/site-packages/pandas/core/indexing.py in _has_valid_tuple(self, key)
#     228         for i, k in enumerate(key):
#     229             if i >= self.obj.ndim:
# --> 230                 raise IndexingError("Too many indexers")
#     231             try:
#     232                 self._validate_key(k, i)
#
# IndexingError: Too many indexers

# %%
print('selecting the hours_per_week value from row at position 10')
print(adult_income.iloc[10, :].loc['hours-per-week'])
# Out:
# selecting the hours_per_week value from row at position 10
# 40
